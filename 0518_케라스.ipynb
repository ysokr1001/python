# %% [markdown]
# <a href="https://colab.research.google.com/github/ysokr1001/python/blob/main/0518_%EC%BC%80%EB%9D%BC%EC%8A%A4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import numpy as np

tf.set_random_seed(0)

Data_Set = np.loadtxt("drive/MyDrive/Colab Notebooks/ThoraricSurgery.csv", delimiter = ",")
x_data = Data_set[:,0:17]
y_data = Data_Set[:,[17]]

X = tf.placeholder(tf.float32, shape = [None, 17])
Y = tf.placeholder(tf.float32, shape = [None, 1])

W1 = tf.Variable(tf.random_normal([17, 30]), name = 'weight1')
b1 = tf.Variable(tf.random_normal([5]), name= 'bias1')
layer1 = tf.sigmoid(tf.matmul(X,W1)+b1)
W2 = tf.Variable(tf.random_normal([30, 1]), name = 'weight2')
b2 = tf.Variable(tf.random_normal([1]), name= 'bias2')
hypothesis = tf.sifmoid(tf.matmul(layer1,W2)+b2)

cost = -tf.reduce_mean(Y * tf.log(hypothesis)  + (1 - Y) * tf.log(1-hypothesis))
train = tf.train.FradientDescentOptimizer(lerning_rate).minimize(cost)

predicted = tf.cast(hypothesis > 0.5, dtype = tf.float32)
accuracy = tf.reduce_mean(tf.cast(tf.equal(predicted, Y), dtype=tf.float32))

with tf.Session() as sess:
  sess.run(tf.global_variables_initializer())
  
  for step in range(10001):
    sess.run(train, feed_dict={X:x_data, Y:y_data})
    if step % 1000 == 0:
      print(step, sess.run(cost, feed_dict={X:x_data, Y:y_data}))

    h, c, a = sess.run([hypothesis, predicted, accuracy], feed_dict={X:x_data, Y:y_data})
    print("\nHypothesis: \n" ,h, "\nCorrect:\n" ,c, "\nAccuracy: \n" , a)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
import numpy
import tensorflow as tf
seed = 0 
numpy.random.seed(seed)
tf.random.set_seed(seed)

Data_set = numpy.loadtxt("drive/MyDrive/Colab Notebooks/ThoraricSurgery.csv", delimiter = ",")
X= Data_set[:,0:17]
Y = Data_Set[:,[17]]

model = Sequential()
model.add(Dense(30, input_dim=17, activation='sigmoid'))
model.add(Dense(1, activation = 'sigmoid'))

model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
model.fit(X, Y, epochs=30, batch_size=10)

print("\n Accuracy: %.4f"%(model.evaluate(X, Y)[1]))

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Activation, Dense
import numpy as np

training_data = np.array([[0,0], [0,1], [1,0], [1,1]], "float32")
target_data= np.array([[0], [1], [1], [0]], "float32")

model = Sequential()

model.add(Dense(4, input_dim=2, activation='relu'))
model.add(Dense(1, activation = 'sigmoid'))

model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
model.fit(training_data, target_data, epochs=1000, verbose=2)

print(model.predict(training_data))
print("\n Accuracy: %.4f"%(model.evaluate(training_data,target_data)[1]))

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Activation, Dense
import numpy as np
from tensorflow.keras import optimizers

training_data = np.array([[0,0], [0,1], [1,0], [1,1]], "float32")
target_data= np.array([[0], [1], [1], [0]], "float32")

model = Sequential()
model.add(Dense(4, input_dim=2, activation='sigmoid'))
model.add(Dense(1, activation = 'sigmoid'))

# opt = optimizers.Adam(lr = 0.1)

model.compile(loss='binary_crossentropy', optimizer=optimizers.Adam(lr=0.1), metrics=['binary_accuracy'])
model.fit(training_data, target_data, epochs=1000, verbose=2)

print(model.predict(training_data))
print("\n Accuracy: %.4f"%(model.evaluate(training_data,target_data)[1]))
# Out:
# Epoch 1/1000
# 1/1 - 0s - loss: 0.6943 - binary_accuracy: 0.2500
# Epoch 2/1000
# 1/1 - 0s - loss: 0.7088 - binary_accuracy: 0.5000
# Epoch 3/1000
# 1/1 - 0s - loss: 0.6935 - binary_accuracy: 0.5000
# Epoch 4/1000
# 1/1 - 0s - loss: 0.6977 - binary_accuracy: 0.5000
# Epoch 5/1000
# 1/1 - 0s - loss: 0.7012 - binary_accuracy: 0.5000
# Epoch 6/1000
# 1/1 - 0s - loss: 0.6963 - binary_accuracy: 0.5000
# Epoch 7/1000
# 1/1 - 0s - loss: 0.6917 - binary_accuracy: 0.5000
# Epoch 8/1000
# 1/1 - 0s - loss: 0.6922 - binary_accuracy: 0.5000
# Epoch 9/1000
# 1/1 - 0s - loss: 0.6947 - binary_accuracy: 0.5000
# Epoch 10/1000
# 1/1 - 0s - loss: 0.6944 - binary_accuracy: 0.5000
# Epoch 11/1000
# 1/1 - 0s - loss: 0.6914 - binary_accuracy: 0.5000
# Epoch 12/1000
# 1/1 - 0s - loss: 0.6888 - binary_accuracy: 0.5000
# Epoch 13/1000
# 1/1 - 0s - loss: 0.6882 - binary_accuracy: 0.5000
# Epoch 14/1000
# 1/1 - 0s - loss: 0.6886 - binary_accuracy: 0.5000
# Epoch 15/1000
# ...

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
import numpy
import tensorflow as tf
seed = 0 
numpy.random.seed(seed)
tf.random.set_seed(seed)

Data_set = numpy.loadtxt("drive/MyDrive/Colab Notebooks/data-03-diabetes (1).csv", delimiter = ",")
X= Data_set[:,0:-1]
Y = Data_set[:,[-1]]

model = Sequential()
model.add(Dense(30, input_dim=8, activation='relu'))
model.add(Dense(30, activation='relu'))
model.add(Dense(1, activation = 'sigmoid'))

model.compile(loss='mean_squared_error', optimizer='adam', metrics=['accuracy'])
model.fit(X, Y, epochs=30, batch_size=10)

print(model.evaluate(X, Y))
# Out:
# Epoch 1/30
# 76/76 [==============================] - 0s 1ms/step - loss: 0.2272 - accuracy: 0.5825
# Epoch 2/30
# 76/76 [==============================] - 0s 1ms/step - loss: 0.1876 - accuracy: 0.7042
# Epoch 3/30
# 76/76 [==============================] - 0s 2ms/step - loss: 0.1667 - accuracy: 0.7526
# Epoch 4/30
# 76/76 [==============================] - 0s 1ms/step - loss: 0.1633 - accuracy: 0.7567
# Epoch 5/30
# 76/76 [==============================] - 0s 1ms/step - loss: 0.1512 - accuracy: 0.7738
# Epoch 6/30
# 76/76 [==============================] - 0s 1ms/step - loss: 0.1517 - accuracy: 0.7794
# Epoch 7/30
# 76/76 [==============================] - 0s 1ms/step - loss: 0.1624 - accuracy: 0.7705
# Epoch 8/30
# 76/76 [==============================] - 0s 1ms/step - loss: 0.1467 - accuracy: 0.7722
# Epoch 9/30
# 76/76 [==============================] - 0s 1ms/step - loss: 0.1545 - accuracy: 0.7803
# Epoch 10/30
# ...
